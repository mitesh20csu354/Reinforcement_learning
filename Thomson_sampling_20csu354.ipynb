# %% [markdown]
# <a href="https://colab.research.google.com/github/mitesh20csu354/Reinforcement_learning/blob/main/Thomson_sampling_20csu354.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#MITESH_KAPIL
#20CSU_354

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Ads_Optimisation.csv')

# %%
df.shape
# Out:
# (10000, 10)

# %%
import random

N = df.shape[0]
d = df.shape[1]
ads_selected = []
number_of_rewards_1 = [0] * d
number_of_rewards_0 = [0] * d
total_reward = 0

for n in range(10000):
    ad = 0
    max_random_beta = 0
    for i in range(d):
        random_beta = random.betavariate(number_of_rewards_1[i] + 1, number_of_rewards_0[i] + 1)
        if random_beta > max_random_beta:
            max_random_beta = random_beta
            ad = i
    ads_selected.append(ad)
    reward = df.iloc[n, ad]
    if reward == 1:
        number_of_rewards_1[ad] += 1
    else:
        number_of_rewards_0[ad] += 1
    total_reward += reward
print(total_reward)
# Out:
# 2572

# %%
print(ads_selected)
# Out:
# [6, 0, 5, 1, 1, 4, 2, 7, 3, 9, 9, 7, 8, 2, 5, 5, 8, 4, 1, 0, 2, 8, 1, 3, 8, 2, 7, 6, 7, 1, 0, 0, 3, 7, 1, 7, 4, 6, 6, 1, 8, 4, 3, 4, 3, 9, 1, 4, 4, 9, 0, 4, 1, 9, 0, 4, 4, 7, 7, 0, 0, 6, 1, 5, 7, 0, 7, 0, 5, 4, 0, 2, 9, 3, 0, 9, 0, 0, 8, 2, 7, 7, 7, 8, 5, 7, 4, 3, 7, 7, 7, 7, 7, 5, 7, 8, 0, 7, 6, 7, 7, 1, 7, 7, 4, 4, 7, 7, 7, 2, 7, 9, 8, 7, 7, 1, 4, 4, 6, 7, 7, 4, 7, 7, 7, 0, 4, 7, 8, 4, 7, 9, 6, 7, 9, 4, 6, 0, 7, 1, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 3, 7, 4, 7, 7, 9, 2, 6, 7, 4, 7, 7, 4, 7, 7, 4, 7, 7, 7, 4, 9, 7, 7, 7, 7, 7, 7, 1, 7, 5, 6, 7, 0, 0, 7, 4, 4, 7, 4, 4, 4, 7, 7, 4, 4, 7, 7, 4, 4, 2, 7, 7, 7, 4, 4, 3, 4, 4, 4, 6, 7, 4, 4, 4, 4, 7, 7, 1, 7, 4, 4, 1, 0, 4, 4, 4, 4, 6, 7, 3, 3, 7, 2, 7, 7, 4, 7, 3, 4, 5, 3, 5, 3, 7, 4, 1, 4, 2, 7, 1, 7, 7, 4, 7, 2, 1, 4, 6, 7, 7, 6, 4, 7, 7, 3, 3, 5, 4, 7, 4, 7, 4, 7, 7, 7, 4, 4, 7, 7, 4, 9, 4, 3, 7, 0, 7, 7, 7, 0, 7, 7, 4, 3, 4, 7, 4, 7, 7, 6, 7, 7, 4, 4, 3, 7, 7, 7, 7, 7, 7, 4, 7, 4, 7, 7, 7, 5, 7, 4, 4, 7, 7, 7, 7, 7, 3, 2, 4, 7, 7, 7, 7, 7
# ...

# %%
plt.hist(ads_selected)
plt.title('Histogram of ads selections')
plt.xlabel('ads')
plt.ylabel('Number of times each ad was selected by the selected by the algorithm')
# Out:
# Text(0, 0.5, 'Number of times each ad was selected by the selected by the algorithm')
